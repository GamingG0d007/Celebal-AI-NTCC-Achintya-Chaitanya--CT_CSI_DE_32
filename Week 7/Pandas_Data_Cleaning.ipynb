# %% [markdown]
# # Pandas Data Exploration and Cleaning

# %%
import pandas as pd

df = pd.read_csv("./Superstore.csv", encoding="latin1")
df.head()
# Out:
# Running cells with 'Python 3.14.3' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: '"c:/Program Files (x86)/Python314-32/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %%
print(df.shape)
print(df.columns.tolist())
print(df.dtypes)
df.tail()

# %%
print(df.isnull().sum())
df = df.fillna(0)

# %%
filtered_df = df[df['Sales'] > 100]
selected_df = filtered_df[['Order ID','Sales']]
selected_df.head()

# %%
df = df.drop_duplicates()

# %%
if 'price' in df.columns and 'quantity' in df.columns:
    df['total_amount']=df['price']*df['quantity']

# %%
df.to_csv('cleaned_superstore.csv', index=False)
